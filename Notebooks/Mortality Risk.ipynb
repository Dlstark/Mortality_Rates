# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %matplotlib inline

# %%
risk_group1 = pd.read_csv('../Data/mort_risk_0-5_csv_dirty.csv')
risk_group2 = pd.read_csv('../Data/mort_risk_5-25_csv_dirty.csv')
risk_group3 = pd.read_csv('../Data/mort_risk_25-45_csv_dirty.csv')
risk_group4 = pd.read_csv('../Data/mort_risk_45-65_csv_dirty.csv')
risk_group5 = pd.read_csv('../Data/mort_risk_65-85_csv_dirty.csv')

# %%
risk_group1
# Out:
#            Location        County Mortality risk, 1980* Mortality risk, 1985*  \
# 0     United States  All counties     1.55 (1.54, 1.57)     1.26 (1.25, 1.27)
# 1           Alabama  All counties     1.91 (1.89, 1.93)     1.57 (1.55, 1.59)
# 2           Alabama       Autauga     1.83 (1.65, 2.01)     1.52 (1.37, 1.67)
# 3           Alabama       Baldwin     1.66 (1.54, 1.78)     1.36 (1.27, 1.46)
# 4           Alabama       Barbour     2.19 (1.96, 2.44)     1.79 (1.62, 1.99)
# ...             ...           ...                   ...                   ...
# 3187        Wyoming    Sweetwater     1.53 (1.38, 1.69)     1.24 (1.12, 1.36)
# 3188        Wyoming         Teton     1.37 (1.18, 1.58)     1.07 (0.93, 1.23)
# 3189        Wyoming         Uinta     1.50 (1.33, 1.70)     1.23 (1.09, 1.38)
# 3190        Wyoming      Washakie     1.49 (1.29, 1.73)     1.22 (1.06, 1.41)
# 3191        Wyoming        Weston     1.74 (1.49, 2.01)     1.38 (1.20, 1.60)
#
# ...

# %%
risk_group1 = risk_group1.drop(columns=['% Change in mortality risk, 1980-2014'])
risk_group2 = risk_group2.drop(columns=['% Change in mortality risk, 1980-2014'])
risk_group3 = risk_group3.drop(columns=['% Change in mortality risk, 1980-2014'])
risk_group4 = risk_group4.drop(columns=['% Change in mortality risk, 1980-2014'])
risk_group5 = risk_group5.drop(columns=['% Change in mortality risk, 1980-2014'])

# %%
risk_group1[['AVG M/R 1980', 'Male M/R 1980', 'Female M/R 1980']] = risk_group1['Mortality risk, 1980*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 1980*', axis=1)
risk_group1
# Out:
#            Location        County Mortality risk, 1985* Mortality risk, 1990*  \
# 0     United States  All counties     1.26 (1.25, 1.27)     1.13 (1.12, 1.14)
# 1           Alabama  All counties     1.57 (1.55, 1.59)     1.45 (1.43, 1.46)
# 2           Alabama       Autauga     1.52 (1.37, 1.67)     1.41 (1.28, 1.54)
# 3           Alabama       Baldwin     1.36 (1.27, 1.46)     1.25 (1.16, 1.34)
# 4           Alabama       Barbour     1.79 (1.62, 1.99)     1.66 (1.48, 1.84)
# ...             ...           ...                   ...                   ...
# 3187        Wyoming    Sweetwater     1.24 (1.12, 1.36)     1.14 (1.03, 1.25)
# 3188        Wyoming         Teton     1.07 (0.93, 1.23)     0.92 (0.80, 1.05)
# 3189        Wyoming         Uinta     1.23 (1.09, 1.38)     1.16 (1.04, 1.31)
# 3190        Wyoming      Washakie     1.22 (1.06, 1.41)     1.12 (0.97, 1.30)
# 3191        Wyoming        Weston     1.38 (1.20, 1.60)     1.22 (1.05, 1.41)
#
# ...

# %%
risk_group1[['AVG M/R 1985', 'Male M/R 1985', 'Female M/R 1985']] = risk_group1['Mortality risk, 1985*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 1985*', axis=1)
risk_group1[['AVG M/R 1990', 'Male M/R 1990', 'Female M/R 1990']] = risk_group1['Mortality risk, 1990*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 1990*', axis=1)
risk_group1[['AVG M/R 1995', 'Male M/R 1995', 'Female M/R 1995']] = risk_group1['Mortality risk, 1995*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 1995*', axis=1)
risk_group1[['AVG M/R 2000', 'Male M/R 2000', 'Female M/R 2000']] = risk_group1['Mortality risk, 2000*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 2000*', axis=1)
risk_group1[['AVG M/R 2005', 'Male M/R 2005', 'Female M/R 2005']] = risk_group1['Mortality risk, 2005*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 2005*', axis=1)
risk_group1[['AVG M/R 2010', 'Male M/R 2010', 'Female M/R 2010']] = risk_group1['Mortality risk, 2010*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 2010*', axis=1)
risk_group1[['AVG M/R 2014', 'Male M/R 2014', 'Female M/R 2014']] = risk_group1['Mortality risk, 2014*'].str.split(expand=True)
risk_group1 = risk_group1.drop('Mortality risk, 2014*', axis=1)
#risk_group1[['AVG M/R Change 1980-2014', 'Male M/R Change 1980-2014', 'Female M/R Change 1980-2014']] = risk_group1['% Change in mortality risk, 1980-2014'].str.split(expand=True)
#risk_group1 = risk_group1.drop('% Change in mortality risk, 1980-2014', axis=1)
risk_group1
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         1.55        (1.54,           1.57)
# 1           Alabama  All counties         1.91        (1.89,           1.93)
# 2           Alabama       Autauga         1.83        (1.65,           2.01)
# 3           Alabama       Baldwin         1.66        (1.54,           1.78)
# 4           Alabama       Barbour         2.19        (1.96,           2.44)
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         1.53        (1.38,           1.69)
# 3188        Wyoming         Teton         1.37        (1.18,           1.58)
# 3189        Wyoming         Uinta         1.50        (1.33,           1.70)
# 3190        Wyoming      Washakie         1.49        (1.29,           1.73)
# 3191        Wyoming        Weston         1.74        (1.49,           2.01)
#
# ...

# %%
for col in risk_group1.columns:
    risk_group1[col] = risk_group1[col].str.replace('(', '').str.replace(')', '').str.replace(',', '')
risk_group1
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         1.55          1.54            1.57
# 1           Alabama  All counties         1.91          1.89            1.93
# 2           Alabama       Autauga         1.83          1.65            2.01
# 3           Alabama       Baldwin         1.66          1.54            1.78
# 4           Alabama       Barbour         2.19          1.96            2.44
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         1.53          1.38            1.69
# 3188        Wyoming         Teton         1.37          1.18            1.58
# 3189        Wyoming         Uinta         1.50          1.33            1.70
# 3190        Wyoming      Washakie         1.49          1.29            1.73
# 3191        Wyoming        Weston         1.74          1.49            2.01
#
# ...

# %%
risk_group2[['AVG M/R 1980', 'Male M/R 1980', 'Female M/R 1980']] = risk_group2['Mortality risk, 1980*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 1980*', axis=1)
risk_group2[['AVG M/R 1985', 'Male M/R 1985', 'Female M/R 1985']] = risk_group2['Mortality risk, 1985*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 1985*', axis=1)
risk_group2[['AVG M/R 1990', 'Male M/R 1990', 'Female M/R 1990']] = risk_group2['Mortality risk, 1990*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 1990*', axis=1)
risk_group2[['AVG M/R 1995', 'Male M/R 1995', 'Female M/R 1995']] = risk_group2['Mortality risk, 1995*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 1995*', axis=1)
risk_group2[['AVG M/R 2000', 'Male M/R 2000', 'Female M/R 2000']] = risk_group2['Mortality risk, 2000*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 2000*', axis=1)
risk_group2[['AVG M/R 2005', 'Male M/R 2005', 'Female M/R 2005']] = risk_group2['Mortality risk, 2005*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 2005*', axis=1)
risk_group2[['AVG M/R 2010', 'Male M/R 2010', 'Female M/R 2010']] = risk_group2['Mortality risk, 2010*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 2010*', axis=1)
risk_group2[['AVG M/R 2014', 'Male M/R 2014', 'Female M/R 2014']] = risk_group2['Mortality risk, 2014*'].str.split(expand=True)
risk_group2 = risk_group2.drop('Mortality risk, 2014*', axis=1)
#risk_group2[['AVG M/R Change 1980-2014', 'Male M/R Change 1980-2014', 'Female M/R Change 1980-2014']] = risk_group2['% Change in mortality risk, 1980-2014'].str.split(expand=True)
#risk_group2 = risk_group2.drop('% Change in mortality risk, 1980-2014', axis=1)
risk_group2
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         1.43        (1.42,           1.43)
# 1           Alabama  All counties         1.76        (1.74,           1.78)
# 2           Alabama       Autauga         1.90        (1.74,           2.08)
# 3           Alabama       Baldwin         1.72        (1.60,           1.84)
# 4           Alabama       Barbour         2.06        (1.88,           2.27)
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         1.88        (1.71,           2.06)
# 3188        Wyoming         Teton         1.47        (1.29,           1.69)
# 3189        Wyoming         Uinta         1.65        (1.46,           1.85)
# 3190        Wyoming      Washakie         1.57        (1.37,           1.79)
# 3191        Wyoming        Weston         1.78        (1.56,           2.04)
#
# ...

# %%
for col in risk_group2.columns:
    risk_group2[col] = risk_group2[col].str.replace('(', '').str.replace(')', '').str.replace(',', '')
risk_group2
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         1.43          1.42            1.43
# 1           Alabama  All counties         1.76          1.74            1.78
# 2           Alabama       Autauga         1.90          1.74            2.08
# 3           Alabama       Baldwin         1.72          1.60            1.84
# 4           Alabama       Barbour         2.06          1.88            2.27
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         1.88          1.71            2.06
# 3188        Wyoming         Teton         1.47          1.29            1.69
# 3189        Wyoming         Uinta         1.65          1.46            1.85
# 3190        Wyoming      Washakie         1.57          1.37            1.79
# 3191        Wyoming        Weston         1.78          1.56            2.04
#
# ...

# %%
risk_group3[['AVG M/R 1980', 'Male M/R 1980', 'Female M/R 1980']] = risk_group3['Mortality risk, 1980*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 1980*', axis=1)
risk_group3[['AVG M/R 1985', 'Male M/R 1985', 'Female M/R 1985']] = risk_group3['Mortality risk, 1985*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 1985*', axis=1)
risk_group3[['AVG M/R 1990', 'Male M/R 1990', 'Female M/R 1990']] = risk_group3['Mortality risk, 1990*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 1990*', axis=1)
risk_group3[['AVG M/R 1995', 'Male M/R 1995', 'Female M/R 1995']] = risk_group3['Mortality risk, 1995*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 1995*', axis=1)
risk_group3[['AVG M/R 2000', 'Male M/R 2000', 'Female M/R 2000']] = risk_group3['Mortality risk, 2000*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 2000*', axis=1)
risk_group3[['AVG M/R 2005', 'Male M/R 2005', 'Female M/R 2005']] = risk_group3['Mortality risk, 2005*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 2005*', axis=1)
risk_group3[['AVG M/R 2010', 'Male M/R 2010', 'Female M/R 2010']] = risk_group3['Mortality risk, 2010*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 2010*', axis=1)
risk_group3[['AVG M/R 2014', 'Male M/R 2014', 'Female M/R 2014']] = risk_group3['Mortality risk, 2014*'].str.split(expand=True)
risk_group3 = risk_group3.drop('Mortality risk, 2014*', axis=1)
#risk_group3[['AVG M/R Change 1980-2014', 'Male M/R Change 1980-2014', 'Female M/R Change 1980-2014']] = risk_group3['% Change in mortality risk, 1980-2014'].str.split(expand=True)
#risk_group3 = risk_group3.drop('% Change in mortality risk, 1980-2014', axis=1)
risk_group3
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         3.60        (3.59,           3.61)
# 1           Alabama  All counties         4.27        (4.23,           4.30)
# 2           Alabama       Autauga         4.00        (3.72,           4.28)
# 3           Alabama       Baldwin         3.78        (3.58,           3.96)
# 4           Alabama       Barbour         4.34        (4.01,           4.65)
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         3.56        (3.29,           3.82)
# 3188        Wyoming         Teton         2.82        (2.53,           3.17)
# 3189        Wyoming         Uinta         3.42        (3.12,           3.74)
# 3190        Wyoming      Washakie         3.33        (2.99,           3.70)
# 3191        Wyoming        Weston         3.89        (3.49,           4.33)
#
# ...

# %%
for col in risk_group3.columns:
    risk_group3[col] = risk_group3[col].str.replace('(', '').str.replace(')', '').str.replace(',', '')
risk_group3
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties         3.60          3.59            3.61
# 1           Alabama  All counties         4.27          4.23            4.30
# 2           Alabama       Autauga         4.00          3.72            4.28
# 3           Alabama       Baldwin         3.78          3.58            3.96
# 4           Alabama       Barbour         4.34          4.01            4.65
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater         3.56          3.29            3.82
# 3188        Wyoming         Teton         2.82          2.53            3.17
# 3189        Wyoming         Uinta         3.42          3.12            3.74
# 3190        Wyoming      Washakie         3.33          2.99            3.70
# 3191        Wyoming        Weston         3.89          3.49            4.33
#
# ...

# %%
risk_group4[['AVG M/R 1980', 'Male M/R 1980', 'Female M/R 1980']] = risk_group4['Mortality risk, 1980*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 1980*', axis=1)
risk_group4[['AVG M/R 1985', 'Male M/R 1985', 'Female M/R 1985']] = risk_group4['Mortality risk, 1985*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 1985*', axis=1)
risk_group4[['AVG M/R 1990', 'Male M/R 1990', 'Female M/R 1990']] = risk_group4['Mortality risk, 1990*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 1990*', axis=1)
risk_group4[['AVG M/R 1995', 'Male M/R 1995', 'Female M/R 1995']] = risk_group4['Mortality risk, 1995*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 1995*', axis=1)
risk_group4[['AVG M/R 2000', 'Male M/R 2000', 'Female M/R 2000']] = risk_group4['Mortality risk, 2000*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 2000*', axis=1)
risk_group4[['AVG M/R 2005', 'Male M/R 2005', 'Female M/R 2005']] = risk_group4['Mortality risk, 2005*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 2005*', axis=1)
risk_group4[['AVG M/R 2010', 'Male M/R 2010', 'Female M/R 2010']] = risk_group4['Mortality risk, 2010*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 2010*', axis=1)
risk_group4[['AVG M/R 2014', 'Male M/R 2014', 'Female M/R 2014']] = risk_group4['Mortality risk, 2014*'].str.split(expand=True)
risk_group4 = risk_group4.drop('Mortality risk, 2014*', axis=1)
#risk_group4[['AVG M/R Change 1980-2014', 'Male M/R Change 1980-2014', 'Female M/R Change 1980-2014']] = risk_group4['% Change in mortality risk, 1980-2014'].str.split(expand=True)
#risk_group4 = risk_group4.drop('% Change in mortality risk, 1980-2014', axis=1)
risk_group4
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties        17.75       (17.72,          17.78)
# 1           Alabama  All counties        19.67       (19.53,          19.80)
# 2           Alabama       Autauga        20.11       (19.11,          21.27)
# 3           Alabama       Baldwin        16.39       (15.75,          17.04)
# 4           Alabama       Barbour        20.53       (19.39,          21.67)
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater        15.58       (14.66,          16.52)
# 3188        Wyoming         Teton        12.71       (11.64,          13.83)
# 3189        Wyoming         Uinta        15.49       (14.26,          16.74)
# 3190        Wyoming      Washakie        15.24       (13.97,          16.49)
# 3191        Wyoming        Weston        16.89       (15.49,          18.37)
#
# ...

# %%
for col in risk_group4.columns:
    risk_group4[col] = risk_group4[col].str.replace('(', '').str.replace(')', '').str.replace(',', '')
risk_group4
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties        17.75         17.72           17.78
# 1           Alabama  All counties        19.67         19.53           19.80
# 2           Alabama       Autauga        20.11         19.11           21.27
# 3           Alabama       Baldwin        16.39         15.75           17.04
# 4           Alabama       Barbour        20.53         19.39           21.67
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater        15.58         14.66           16.52
# 3188        Wyoming         Teton        12.71         11.64           13.83
# 3189        Wyoming         Uinta        15.49         14.26           16.74
# 3190        Wyoming      Washakie        15.24         13.97           16.49
# 3191        Wyoming        Weston        16.89         15.49           18.37
#
# ...

# %%
risk_group5[['AVG M/R 1980', 'Male M/R 1980', 'Female M/R 1980']] = risk_group5['Mortality risk, 1980*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 1980*', axis=1)
risk_group5[['AVG M/R 1985', 'Male M/R 1985', 'Female M/R 1985']] = risk_group5['Mortality risk, 1985*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 1985*', axis=1)
risk_group5[['AVG M/R 1990', 'Male M/R 1990', 'Female M/R 1990']] = risk_group5['Mortality risk, 1990*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 1990*', axis=1)
risk_group5[['AVG M/R 1995', 'Male M/R 1995', 'Female M/R 1995']] = risk_group5['Mortality risk, 1995*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 1995*', axis=1)
risk_group5[['AVG M/R 2000', 'Male M/R 2000', 'Female M/R 2000']] = risk_group5['Mortality risk, 2000*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 2000*', axis=1)
risk_group5[['AVG M/R 2005', 'Male M/R 2005', 'Female M/R 2005']] = risk_group5['Mortality risk, 2005*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 2005*', axis=1)
risk_group5[['AVG M/R 2010', 'Male M/R 2010', 'Female M/R 2010']] = risk_group5['Mortality risk, 2010*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 2010*', axis=1)
risk_group5[['AVG M/R 2014', 'Male M/R 2014', 'Female M/R 2014']] = risk_group5['Mortality risk, 2014*'].str.split(expand=True)
risk_group5 = risk_group5.drop('Mortality risk, 2014*', axis=1)
#risk_group5[['AVG M/R Change 1980-2014', 'Male M/R Change 1980-2014', 'Female M/R Change 1980-2014']] = risk_group5['% Change in mortality risk, 1980-2014'].str.split(expand=True)
#risk_group5 = risk_group5.drop('% Change in mortality risk, 1980-2014', axis=1)
risk_group5
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties        63.89       (63.84,          63.94)
# 1           Alabama  All counties        65.00       (64.75,          65.24)
# 2           Alabama       Autauga        66.76       (64.76,          68.79)
# 3           Alabama       Baldwin        61.16       (59.65,          62.52)
# 4           Alabama       Barbour        65.71       (63.72,          67.65)
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater        63.06       (60.77,          65.23)
# 3188        Wyoming         Teton        58.44       (54.87,          61.91)
# 3189        Wyoming         Uinta        59.32       (56.26,          62.26)
# 3190        Wyoming      Washakie        61.80       (58.97,          64.59)
# 3191        Wyoming        Weston        63.99       (60.88,          67.08)
#
# ...

# %%
for col in risk_group5.columns:
    risk_group5[col] = risk_group5[col].str.replace('(', '').str.replace(')', '').str.replace(',', '')
risk_group5
# Out:
#            Location        County AVG M/R 1980 Male M/R 1980 Female M/R 1980  \
# 0     United States  All counties        63.89         63.84           63.94
# 1           Alabama  All counties        65.00         64.75           65.24
# 2           Alabama       Autauga        66.76         64.76           68.79
# 3           Alabama       Baldwin        61.16         59.65           62.52
# 4           Alabama       Barbour        65.71         63.72           67.65
# ...             ...           ...          ...           ...             ...
# 3187        Wyoming    Sweetwater        63.06         60.77           65.23
# 3188        Wyoming         Teton        58.44         54.87           61.91
# 3189        Wyoming         Uinta        59.32         56.26           62.26
# 3190        Wyoming      Washakie        61.80         58.97           64.59
# 3191        Wyoming        Weston        63.99         60.88           67.08
#
# ...

# %%
risk_group1_melt = risk_group1.melt(id_vars=['Location', 'County'],var_name='Var/Year', value_name='Mortality Risk %')
risk_group2_melt = risk_group2.melt(id_vars=['Location', 'County'],var_name='Var/Year', value_name='Mortality Risk %')
risk_group3_melt = risk_group3.melt(id_vars=['Location', 'County'],var_name='Var/Year', value_name='Mortality Risk %')
risk_group4_melt = risk_group4.melt(id_vars=['Location', 'County'],var_name='Var/Year', value_name='Mortality Risk %')
risk_group5_melt = risk_group5.melt(id_vars=['Location', 'County'],var_name='Var/Year', value_name='Mortality Risk %')
risk_group1_melt
# Out:
#             Location        County         Var/Year Mortality Risk %
# 0      United States  All counties     AVG M/R 1980             1.55
# 1            Alabama  All counties     AVG M/R 1980             1.91
# 2            Alabama       Autauga     AVG M/R 1980             1.83
# 3            Alabama       Baldwin     AVG M/R 1980             1.66
# 4            Alabama       Barbour     AVG M/R 1980             2.19
# ...              ...           ...              ...              ...
# 76603        Wyoming    Sweetwater  Female M/R 2014             0.78
# 76604        Wyoming         Teton  Female M/R 2014             0.49
# 76605        Wyoming         Uinta  Female M/R 2014             0.89
# 76606        Wyoming      Washakie  Female M/R 2014             0.77
# 76607        Wyoming        Weston  Female M/R 2014             0.81
#
# [76608 rows x 4 columns]

# %%
risk_group1_melt[['Sex', 'Year']] = risk_group1_melt['Var/Year'].str.split(pat = ' M\/R ', expand = True)
risk_group2_melt[['Sex', 'Year']] = risk_group2_melt['Var/Year'].str.split(pat = ' M\/R ', expand = True)
risk_group3_melt[['Sex', 'Year']] = risk_group3_melt['Var/Year'].str.split(pat = ' M\/R ', expand = True)
risk_group4_melt[['Sex', 'Year']] = risk_group4_melt['Var/Year'].str.split(pat = ' M\/R ', expand = True)
risk_group5_melt[['Sex', 'Year']] = risk_group5_melt['Var/Year'].str.split(pat = ' M\/R ', expand = True)
risk_group1_melt
# Out:
#             Location        County         Var/Year Mortality Risk %     Sex  \
# 0      United States  All counties     AVG M/R 1980             1.55     AVG
# 1            Alabama  All counties     AVG M/R 1980             1.91     AVG
# 2            Alabama       Autauga     AVG M/R 1980             1.83     AVG
# 3            Alabama       Baldwin     AVG M/R 1980             1.66     AVG
# 4            Alabama       Barbour     AVG M/R 1980             2.19     AVG
# ...              ...           ...              ...              ...     ...
# 76603        Wyoming    Sweetwater  Female M/R 2014             0.78  Female
# 76604        Wyoming         Teton  Female M/R 2014             0.49  Female
# 76605        Wyoming         Uinta  Female M/R 2014             0.89  Female
# 76606        Wyoming      Washakie  Female M/R 2014             0.77  Female
# 76607        Wyoming        Weston  Female M/R 2014             0.81  Female
#
#        Year
# 0      1980
# 1      1980
# ...

# %%
risk_group1_melt = risk_group1_melt.drop(columns=['Var/Year'])
risk_group2_melt = risk_group2_melt.drop(columns=['Var/Year'])
risk_group3_melt = risk_group3_melt.drop(columns=['Var/Year'])
risk_group4_melt = risk_group4_melt.drop(columns=['Var/Year'])
risk_group5_melt = risk_group5_melt.drop(columns=['Var/Year'])

# %%
risk_group1_melt['Sex'] = risk_group1_melt['Sex'].str.replace('AVG','Combined')
risk_group2_melt['Sex'] = risk_group2_melt['Sex'].str.replace('AVG','Combined')
risk_group3_melt['Sex'] = risk_group3_melt['Sex'].str.replace('AVG','Combined')
risk_group4_melt['Sex'] = risk_group4_melt['Sex'].str.replace('AVG','Combined')
risk_group5_melt['Sex'] = risk_group5_melt['Sex'].str.replace('AVG','Cpmbined')

# %%
risk_group1_melt
# Out:
#             Location        County Mortality Risk %       Sex  Year
# 0      United States  All counties             1.55  Combined  1980
# 1            Alabama  All counties             1.91  Combined  1980
# 2            Alabama       Autauga             1.83  Combined  1980
# 3            Alabama       Baldwin             1.66  Combined  1980
# 4            Alabama       Barbour             2.19  Combined  1980
# ...              ...           ...              ...       ...   ...
# 76603        Wyoming    Sweetwater             0.78    Female  2014
# 76604        Wyoming         Teton             0.49    Female  2014
# 76605        Wyoming         Uinta             0.89    Female  2014
# 76606        Wyoming      Washakie             0.77    Female  2014
# 76607        Wyoming        Weston             0.81    Female  2014
#
# [76608 rows x 5 columns]

# %%
risk_group1_melt.to_csv('../Data/mort_risk_0-5_csv.csv')
risk_group2_melt.to_csv('../Data/mort_risk_5-25_csv.csv')
risk_group3_melt.to_csv('../Data/mort_risk_25-45_csv.csv')
risk_group4_melt.to_csv('../Data/mort_risk_45-65_csv.csv')
risk_group5_melt.to_csv('../Data/mort_risk_65-85_csv.csv')

# %%
risk_group1_melt['Sex'].value_counts()
# Out:
# Combined    25536
# Male        25536
# Female      25536
# Name: Sex, dtype: int64
